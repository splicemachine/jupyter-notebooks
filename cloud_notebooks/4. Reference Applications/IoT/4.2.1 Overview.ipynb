# %%
# %%HTML
# <link rel="stylesheet" href="https://doc.splicemachine.com/jupyter/css/custom.css">
# Out:
# <link rel="stylesheet" href="https://doc.splicemachine.com/jupyter/css/custom.css">

# %% [markdown]
# # IoT Demo Overview
#
# Splice Machine's Cloud Service makes it easy to stand up a powerful scale-out database that can ingest millions of records while running reports and time series analysis. In this notebook, we:
#
# * Create a Splice Machine database for an Internet of Things project.
# * Start a Kafka stream that is a proxy for the data streams generated by Edge Bridges and other processing.
# * Create a spark streaming process to retrieve data from the kafka queue.
# * Ingest that data into Splice Machine using the Splice Machine Native Spark DataSource.
# * Run real-time queries and reports while simultaneously continuing to ingest data into our Splice Machine database.
#
# This demo uses our cloud infrastructure, which is available on both AWS and Azure.

# %% [markdown]
# ## Notebooks in this Demo
#
# This IoT demonstration contains the following notebooks:
#
# <table class="splicezepOddEven">
#     <tbody>
#         <tr>
#             <td>Database Setup</td>
#             <td>Creates database tables for the static and streaming IoT data.</td>
#         </tr>
#         <tr>
#             <td>Kafka</td>
#             <td>Creates a Kafka producer to add data to the queue that is used for this demo.</td>
#         </tr>
#         <tr>
#             <td>Spark Streaming</td>
#             <td>Captures data from Kafka and inserts it into the Splice Machine database.</td>
#         </tr>
#         <tr>
#             <td>Database Queries</td>
#             <td>Runs real-time queries and reports against the Splice Machine database.</td>
#         </tr>
#     </tbody>
# </table>
#
# Please go through these notebooks in sequence, starting with the [*Database Setup*](./4.2.2%20Database.ipynb) notebook.
